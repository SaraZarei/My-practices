# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats

# %%
df=pd.read_csv('E:\work\DataSets\\automobileEDA.csv')

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
sns.regplot(x='wheel-base',y='price',data=df)

# %%
coefficient,p_value=stats.pearsonr(df['wheel-base'],df['price'])
print('preason_coefficient:',coefficient,'p_value',p_value)
# Out:
# preason_coefficient: 0.5846418222655081 p_value 8.076488270732955e-20

# %%
sns.regplot(x='width',y='price',data=df)
coefficient,p_value=stats.pearsonr(df['width'],df['price'])
print('preason_coefficient:',coefficient,'p_value',p_value)
# Out:
# preason_coefficient: 0.7512653440522674 p_value 9.200335510481426e-38

# %%
sns.regplot(x='length',y='price',data=df)
coefficient,p_value=stats.pearsonr(df['length'],df['price'])
print('preason_coefficient:',coefficient,'p_value',p_value)
# Out:
# preason_coefficient: 0.690628380448364 p_value 8.016477466159053e-30

# %%
sns.regplot(x='bore',y='price',data=df)
coefficient,p_value=stats.pearsonr(df['bore'],df['price'])
print('preason_coefficient:',coefficient,'p_value',p_value)
# Out:
# preason_coefficient: 0.5431553832626602 p_value 8.049189483935364e-17

# %%
sns.regplot(x='horsepower',y='price',data=df)
coefficient,p_value=stats.pearsonr(df['horsepower'],df['price'])
print('preason_coefficient:',coefficient,'p_value',p_value)
# Out:
# preason_coefficient: 0.8095745670036559 p_value 6.36905742825998e-48

# %%
sns.regplot(x='city-mpg',y='price',data=df)
coefficient,p_value=stats.pearsonr(df['city-mpg'],df['price'])
print('preason_coefficient:',coefficient,'p_value',p_value)
# Out:
# preason_coefficient: -0.6865710067844677 p_value 2.3211320655676368e-29
